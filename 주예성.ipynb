# %% [markdown]
# # 1

# %%
maxWeight = 6
rowCount = 4

# 0은 더미데이터
weight = [0, 6, 4, 3, 5]
money = [0, 13, 8, 6, 12]

def knapsack():
    array = [[0 for _ in range(maxWeight + 1)] for _ in range(rowCount + 1)]

    for row in range(1, rowCount+1):
        for col in range(1, maxWeight+1):
            if weight[row] > col:  
                array[row][col] = array[row-1][col]
            else:
                value1 = money[row] + array[row-1][col-weight[row]]  
                value2 = array[row-1][col]
                array[row][col] = max(value1, value2)

    return array[rowCount][maxWeight]

knapsack()
# Out:
# 13

# %% [markdown]
# # 2

# %%
customer = ['정국', '뷔', '지민', '진', '슈가']

def waitingline():
    num = 0
    while True:
        num+=1
        print(f'대기 줄 상태 : {customer}')
        print(f'{customer[0]} 님 식당에 들어감')

        for i in range(0, len(customer)): # 앞 인덱스를 None으로 바꾼 후 뒤와 순차적으로 위치바꿈
            if i != 0:
                customer[i-1] = customer[i]
            customer[i] = None 

        if num == len(customer): # 끝났을 경우 줄 상태 보여주고 종료
            print(f'대기 줄 상태 : {customer}')
            print('식당 영업 종료!')
            break

waitingline()
# Out:
# 대기 줄 상태 : ['정국', '뷔', '지민', '진', '슈가']
# 정국 님 식당에 들어감
# 대기 줄 상태 : ['뷔', '지민', '진', '슈가', None]
# 뷔 님 식당에 들어감
# 대기 줄 상태 : ['지민', '진', '슈가', None, None]
# 지민 님 식당에 들어감
# 대기 줄 상태 : ['진', '슈가', None, None, None]
# 진 님 식당에 들어감
# 대기 줄 상태 : ['슈가', None, None, None, None]
# 슈가 님 식당에 들어감
# 대기 줄 상태 : [None, None, None, None, None]
# 식당 영업 종료!

# %% [markdown]
# # 3

# %%
class TreeNode():
    def __init__ (self):
        self.left = None
        self.data = None
        self.right = None

memory = []
root = None
# dataAry = ['콘말차', '삿포로 맥주', '아카페라 벤티 헤이즐넛', '레어치즈푸딩', '척오리지널 메가 사워', '요아정 요거트컵',
#             '페퍼로니피자주먹밥', '널담 슈톨렌', '딸기마시멜로케이크', '버니공쥬 딸기뚱카롱', '고추잡채호빵', '체다 슈크림붕어스낵']

sellAry = input('오늘 판매된 물건(중복O)<쉼표입력필요> --> ').split(',')

node = TreeNode()
node.data = sellAry[0]
root = node
memory.append(node)

#이진트리
for name in sellAry[1:]:
    node = TreeNode()
    node.data = name

    current = root
    while True:
        if name == current.data: break

        if name < current.data:
            if current.left == None:
                current.left = node
                memory.append(node)
                break
            current = current.left
        else:
            if current.right == None:
                current.right = node
                memory.append(node)
                break
            current = current.right

def preorder(node):
    if node == None: return
    print(node.data, end=' ')
    preorder(node.left)
    preorder(node.right)

print(f'오늘 판매된 물건(중복O) --> {sellAry}')
print('오늘 판매된 종류(중복X) -->', end=' ')
preorder(root)
# Out:
# 오늘 판매된 물건(중복O) --> ['안녕', '안녕']
# 오늘 판매된 종류(중복X) --> 안녕

# %% [markdown]
# # 4

# %%
import random

def binSearch(ary, fData):
    num = 0
    pos = -1
    start = 0
    end = len(ary) - 1

    while (start <= end):
        mid = (start + end) // 2
        
        num += 1
        print(f'## {num}회 검색 ##') # 검색횟수

        if fData == ary[mid]:
            return mid
        elif fData > ary[mid]:
            start = mid + 1
        else:
            end = mid - 1

    return pos

dataAry = []

# 100000번을 랜덤으로 0~100000 중에서 뽑음
for _ in range(100000):
    dataAry.append(random.randint(0,100000))

# 0~100000 중 랜덤으로 찾을 데이터를 뽑음
findData = random.randint(0,100000)

print(f'배열 --> {dataAry}')
position = binSearch(dataAry, findData)
if position == -1:
    print(f'{findData} (이)가 없네요.')
else:
    print(f'{findData} (은)는 {position} 위치에 있음')
# Out:
# 배열 --> [47493, 12079, 83826, 99092, 90330, 61707, 43852, 83600, 18001, 41862, 52344, 22471, 84784, 41501, 21934, 40169, 91255, 91702, 18070, 90101, 45605, 44275, 5631, 65449, 75091, 61229, 52894, 85872, 76859, 722, 35145, 46213, 63743, 16962, 23847, 71485, 17389, 37511, 8556, 37057, 60188, 73674, 29401, 94767, 61779, 24876, 14114, 33567, 24892, 25799, 63112, 96569, 80876, 75557, 45345, 12459, 4534, 95917, 85263, 67199, 84964, 11502, 9274, 5315, 36238, 77762, 73278, 42113, 88524, 32875, 29673, 6009, 95703, 32401, 61853, 15876, 74443, 13941, 96338, 98211, 53888, 93891, 6756, 90309, 43045, 42603, 61704, 77873, 5749, 17254, 62163, 1599, 56010, 71339, 80995, 28624, 69754, 54381, 92999, 42330, 40823, 30494, 97483, 1668, 92260, 69277, 94074, 21755, 29573, 8904, 54453, 68545, 31035, 16800, 88472, 20688, 17295, 97432, 14914, 61333, 69840, 16876, 84269, 92763, 84357, 65404, 91014, 46356, 7954, 23973, 99633, 24313, 71460, 99037, 73970, 43447, 1077, 18536, 573, 8212, 44333, 78638, 33137, 25417, 50148, 31457, 70592, 49952, 60929, 828, 66418, 11944, 49551, 88191, 31269, 38706, 53124, 29143, 41909, 97580, 7148, 23855, 55026, 29483, 81731, 7547, 23447, 66715, 61567, 7219, 18892, 22830, 5299, 50348, 74650, 31770, 67074, 93073, 94006, 56981, 91445, 88259, 88951, 40997, 87459, 40014, 92461, 30022, 14471, 90343, 10448, 69191, 97606, 86718, 91395, 85480, 83662, 15410, 66423, 18055, 99128, 92875, 35630, 31403, 52140, 80408, 61400, 48245, 89810, 30218, 25916, 707, 10345, 10869, 8589, 89184, 22619, 63167, 61336, 43347, 56891, 67796, 50918, 54584, 98126, 98050, 37965, 67906, 89377, 39946, 1697, 34171, 35629, 79044, 40433, 46876, 9188, 89518, 88835, 36418, 13784, 41725, 25537, 25389, 71122, 81234, 23203, 36801, 34927, 99199, 31142, 8189, 27631, 89973, 19441, 35547, 75260, 61469, 62269, 65801, 44614, 62260, 56691, 74345, 77324, 61060, 32290, 67554, 36435, 86344, 6543, 72044, 6790, 5583, 88008,